# %%
import requests

url = "https://real-time-flipkart-api.p.rapidapi.com/products-by-brand"

querystring = {"brand_id":"tyy,4io","page":"1","sort_by":"popularity"}

headers = {
	"x-rapidapi-key": "49fe1f423amshd926de362b7e1a6p1d38eajsned85b0bb1489",
	"x-rapidapi-host": "real-time-flipkart-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
response.json()['products']
# Out:
# [{'pid': 'MOBGTAGPAQNVFZZY',
#   'itemId': 'ITMBF14EF54F645D',
#   'listingId': 'LSTMOBGTAGPAQNVFZZYO7HQ2L',
#   'brand': 'Apple',
#   'title': 'Apple iPhone 15 (Blue, 128 GB)',
#   'subTitle': None,
#   'url': 'https://flipkart.com/apple-iphone-15-blue-128-gb/p/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY',
#   'badge': 'Bestseller',
#   'stock': 'IN_STOCK',
#   'highlights': ['128 GB ROM',
#    '15.49 cm (6.1 inch) Super Retina XDR Display',
#    '48MP + 12MP | 12MP Front Camera',
#    'A16 Bionic Chip, 6 Core Processor Processor'],
#   'isSponsored': False,
#   'mrp': 79600,
#   'price': 69999,
#   'rating': {'average': 4.6,
#    'count': 49159,
#    'reviewCount': 2562,
#    'breakup': [2285, 697, 1486, 6394, 38297]},
#   'images': ['https://rukminim2.flixcart.com/image/1160/1160/xif0q/mobile/k/l/l/-original-imagtc5fz9spysyk.jpeg?q=90',
#    'https://rukminim2.flixcart.com/image/1160/1160/xif0q/mobile/2/7/h/-original-imagtc5fyznz42bx.jpeg?q=90',
# ...

# %%
df = pd.DataFrame(response.json()['products'])[['pid','itemId','listingId','brand','title','badge','stock','highlights','isSponsored','mrp','price','rating']]

# %%
df
# Out:
#                  pid            itemId                  listingId  brand  \
# 0   MOBGTAGPAQNVFZZY  ITMBF14EF54F645D  LSTMOBGTAGPAQNVFZZYO7HQ2L  Apple
# 1   MOBGTAGPDTKHHHZU  ITM825E4AD0B80CA  LSTMOBGTAGPDTKHHHZUTQZRMS  Apple
# 2   MOBGTAGPVSMQYGZX  ITM94BB31F2AF05A  LSTMOBGTAGPVSMQYGZXNTFFPK  Apple
# 3   MOBGHWFHUYWGB5F2  ITMAC8385391B02B  LSTMOBGHWFHUYWGB5F2XIJVA7  Apple
# 4   MOBGTAGPTB3VS24W  ITM6AC6485515AE4  LSTMOBGTAGPTB3VS24WVZNSC6  Apple
# 5   MOBGTAGPE4F2HAW7  ITM4022C14383050  LSTMOBGTAGPE4F2HAW7NDYSPY  Apple
# 6   MOBGTAGPNRQA7CS3  ITME3A53984760FB  LSTMOBGTAGPNRQA7CS3L7XK7L  Apple
# 7   MOBGTAGPJVGHTAYC  ITMAA50ABB5E6C3B  LSTMOBGTAGPJVGHTAYCTGIMN2  Apple
# 8   MOBGHWFH3JX6NWWY  ITM4199EA6BCD38B  LSTMOBGHWFH3JX6NWWYRH38NG  Apple
# 9   MOBFWBYZ8DNJNY7N  ITM5778AD0D0D255  LSTMOBFWBYZ8DNJNY7NMWAWOJ  Apple
# 10  MOBGTAGPNMZA5PU5  ITM7579ED94CA647  LSTMOBGTAGPNMZA5PU51YWTGZ  Apple
# 11  MOBGTAGPYYWZRUJX  ITM235CD318BDE73  LSTMOBGTAGPYYWZRUJXUGY7PM  Apple
# ...

# %%
df.to_csv('flipcart_products.csv')

# %%
df
# Out:
#                  pid            itemId                  listingId  brand  \
# 0   MOBGTAGPAQNVFZZY  ITMBF14EF54F645D  LSTMOBGTAGPAQNVFZZYO7HQ2L  Apple
# 1   MOBGTAGPDTKHHHZU  ITM825E4AD0B80CA  LSTMOBGTAGPDTKHHHZUTQZRMS  Apple
# 2   MOBGTAGPVSMQYGZX  ITM94BB31F2AF05A  LSTMOBGTAGPVSMQYGZXNTFFPK  Apple
# 3   MOBGHWFHUYWGB5F2  ITMAC8385391B02B  LSTMOBGHWFHUYWGB5F2XIJVA7  Apple
# 4   MOBGTAGPTB3VS24W  ITM6AC6485515AE4  LSTMOBGTAGPTB3VS24WVZNSC6  Apple
# 5   MOBGTAGPE4F2HAW7  ITM4022C14383050  LSTMOBGTAGPE4F2HAW7NDYSPY  Apple
# 6   MOBGTAGPNRQA7CS3  ITME3A53984760FB  LSTMOBGTAGPNRQA7CS3L7XK7L  Apple
# 7   MOBGTAGPJVGHTAYC  ITMAA50ABB5E6C3B  LSTMOBGTAGPJVGHTAYCTGIMN2  Apple
# 8   MOBGHWFH3JX6NWWY  ITM4199EA6BCD38B  LSTMOBGHWFH3JX6NWWYRH38NG  Apple
# 9   MOBFWBYZ8DNJNY7N  ITM5778AD0D0D255  LSTMOBFWBYZ8DNJNY7NMWAWOJ  Apple
# 10  MOBGTAGPNMZA5PU5  ITM7579ED94CA647  LSTMOBGTAGPNMZA5PU51YWTGZ  Apple
# 11  MOBGTAGPYYWZRUJX  ITM235CD318BDE73  LSTMOBGTAGPYYWZRUJXUGY7PM  Apple
# ...

# %%
sk=pd.read_csv('flipcart_products.csv')

# %%
sk
# Out:
#     Unnamed: 0               pid            itemId                  listingId  \
# 0            0  MOBGTAGPAQNVFZZY  ITMBF14EF54F645D  LSTMOBGTAGPAQNVFZZYO7HQ2L
# 1            1  MOBGTAGPDTKHHHZU  ITM825E4AD0B80CA  LSTMOBGTAGPDTKHHHZUTQZRMS
# 2            2  MOBGTAGPVSMQYGZX  ITM94BB31F2AF05A  LSTMOBGTAGPVSMQYGZXNTFFPK
# 3            3  MOBGHWFHUYWGB5F2  ITMAC8385391B02B  LSTMOBGHWFHUYWGB5F2XIJVA7
# 4            4  MOBGTAGPTB3VS24W  ITM6AC6485515AE4  LSTMOBGTAGPTB3VS24WVZNSC6
# 5            5  MOBGTAGPE4F2HAW7  ITM4022C14383050  LSTMOBGTAGPE4F2HAW7NDYSPY
# 6            6  MOBGTAGPNRQA7CS3  ITME3A53984760FB  LSTMOBGTAGPNRQA7CS3L7XK7L
# 7            7  MOBGTAGPJVGHTAYC  ITMAA50ABB5E6C3B  LSTMOBGTAGPJVGHTAYCTGIMN2
# 8            8  MOBGHWFH3JX6NWWY  ITM4199EA6BCD38B  LSTMOBGHWFH3JX6NWWYRH38NG
# 9            9  MOBFWBYZ8DNJNY7N  ITM5778AD0D0D255  LSTMOBFWBYZ8DNJNY7NMWAWOJ
# 10          10  MOBGTAGPNMZA5PU5  ITM7579ED94CA647  LSTMOBGTAGPNMZA5PU51YWTGZ
# ...

# %%
sk.isnull().sum()
# Out:
# Unnamed: 0      0
# pid             0
# itemId          0
# listingId       0
# brand           0
# title           0
# badge          22
# stock           0
# highlights      0
# isSponsored     0
# mrp             0
# price           0
# rating          0
# dtype: int64

# %%
sk.fillna
# Out:
# <bound method NDFrame.fillna of     Unnamed: 0               pid            itemId                  listingId  \
# 0            0  MOBGTAGPAQNVFZZY  ITMBF14EF54F645D  LSTMOBGTAGPAQNVFZZYO7HQ2L
# 1            1  MOBGTAGPDTKHHHZU  ITM825E4AD0B80CA  LSTMOBGTAGPDTKHHHZUTQZRMS
# 2            2  MOBGTAGPVSMQYGZX  ITM94BB31F2AF05A  LSTMOBGTAGPVSMQYGZXNTFFPK
# 3            3  MOBGHWFHUYWGB5F2  ITMAC8385391B02B  LSTMOBGHWFHUYWGB5F2XIJVA7
# 4            4  MOBGTAGPTB3VS24W  ITM6AC6485515AE4  LSTMOBGTAGPTB3VS24WVZNSC6
# 5            5  MOBGTAGPE4F2HAW7  ITM4022C14383050  LSTMOBGTAGPE4F2HAW7NDYSPY
# 6            6  MOBGTAGPNRQA7CS3  ITME3A53984760FB  LSTMOBGTAGPNRQA7CS3L7XK7L
# 7            7  MOBGTAGPJVGHTAYC  ITMAA50ABB5E6C3B  LSTMOBGTAGPJVGHTAYCTGIMN2
# 8            8  MOBGHWFH3JX6NWWY  ITM4199EA6BCD38B  LSTMOBGHWFH3JX6NWWYRH38NG
# 9            9  MOBFWBYZ8DNJNY7N  ITM5778AD0D0D255  LSTMOBFWBYZ8DNJNY7NMWAWOJ
# 10          10  MOBGTAGPNMZA5PU5  ITM7579ED94CA647  LSTMOBGTAGPNMZA5PU51YWTGZ
# ...

# %%
sk.badge
# Out:
# 0     Bestseller
# 1            NaN
# 2            NaN
# 3            NaN
# 4     Bestseller
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# Name: badge, dtype: object

# %%
sk.rating
# Out:
# 0     {'average': 4.6, 'count': 49159, 'reviewCount'...
# 1     {'average': 4.6, 'count': 49159, 'reviewCount'...
# 2     {'average': 4.6, 'count': 8790, 'reviewCount':...
# 3     {'average': 4.6, 'count': 80132, 'reviewCount'...
# 4     {'average': 4.6, 'count': 49159, 'reviewCount'...
# 5     {'average': 4.6, 'count': 8790, 'reviewCount':...
# 6     {'average': 4.6, 'count': 8790, 'reviewCount':...
# 7     {'average': 4.6, 'count': 8790, 'reviewCount':...
# 8     {'average': 4.6, 'count': 80132, 'reviewCount'...
# 9     {'average': 4.6, 'count': 210928, 'reviewCount...
# 10    {'average': 4.6, 'count': 49159, 'reviewCount'...
# 11    {'average': 4.6, 'count': 49159, 'reviewCount'...
# 12    {'average': 4.6, 'count': 284030, 'reviewCount...
# 13    {'average': 4.6, 'count': 284030, 'reviewCount...
# 14    {'average': 4.6, 'count': 284030, 'reviewCount...
# 15    {'average': 4.6, 'count': 80132, 'reviewCount'...
# 16    {'average': 4.6, 'count': 284030, 'reviewCount...
# ...
